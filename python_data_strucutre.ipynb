# %% [markdown]
# <a href="https://colab.research.google.com/github/ishasaini24/-first-repository/blob/main/python_data_strucutre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list data structure
lst=[1,4,6,7,8]
lst
# Out:
# [1, 4, 6, 7, 8]

# %%
fruits=["mango", "apple","banana","cherry"]
#fruits
print(fruits[3])
print(fruits[-1])
fruits[3]="dragonfruit"
fruits.append("pomegranate")
fruits.insert(1,"raddish")
fruits.pop(2)
fruits.sort(ascending=False)

fruits
# Out:
# cherry
# cherry
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13670/2969830449.py in <cell line: 0>()
#       7 fruits.insert(1,"raddish")
#       8 fruits.pop(2)
# ----> 9 fruits.sort(ascending=False)
#      10
#      11 fruits
#
# TypeError: 'ascending' is an invalid keyword argument for sort()

# %%
fruits=["mango", "apple","banana","cherry"]
fruits.sort(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13670/1718201944.py in <cell line: 0>()
#       1 fruits=["mango", "apple","banana","cherry"]
# ----> 2 fruits.sort(ascending=False)
#
# TypeError: 'ascending' is an invalid keyword argument for sort()

# %%
fruits=["mango", "apple","banana","cherry"]
fruits.reverse()
fruits
# Out:
# ['cherry', 'banana', 'apple', 'mango']

# %%
list=[6,99,6,44,97,64,8,8,8]
list[::-1]
list.clear()
#list comprehension
[x**2 for x in range (10) if x%2==0]
# Out:
# [0, 4, 16, 36, 64]

# %%
#tuple data structure
tup=()
print(type(tup))
numbers=tuple([5,8,7,5,8])
print(type(numbers))
numbers[4]
mixed_tuple=(88,"hello","isha",8.99)
mixed_tuple
#concatenation
concat=numbers+mixed_tuple
concat
#mixed_tuple*3
#numbers[2]="isha"=tuple not support item assignment
print(numbers.count(1))
print(numbers.index(8))
#packing and unpacking tuple
packed_tuple=(7,9,"hello",9.88)
print(packed_tuple)
#unpack
a,b,c,d=packed_tuple
print(a)
print(b)
print(c)
print(d)
#unpacking with *
Numbers=(1,5,7,6,8,4,5)
first,middle,*last=Numbers
print(first)
print(middle)
print(last)
#nested tuple
nested=((7,5,5,4),(6,7,4,58,8),(7,4,6,7,8,5))
print(nested[1][3])
#nested list is also same

# A function to find duplicate elements in a list

def find_duplicates(lst):
  duplicate=[]
  for item in (lst):
    if lst.count(item)>1 and item not in duplicate:
      duplicate.append(item)
  return duplicate
lst=[1,1,2,2,3,3,3,4,4,9]
print(find_duplicates(lst))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# 0
# 1
# (7, 9, 'hello', 9.88)
# 7
# 9
# hello
# 9.88
# 1
# 5
# [7, 6, 8, 4, 5]
# 58
# [1, 2, 3, 4]
